# %%
from sklearn import datasets
import pandas as pd
import numpy  as np

# %%
 wine = datasets.load_wine()
 x = pd.DataFrame(wine['data'], columns = wine['feature_names'])
 print("target_names:"+str(wine['target_names']))
 y = pd.DataFrame(wine['target'], columns = ['target'])
 data = pd.concat([x,y], axis=1)
 data.head(178)
# Out:
# target_names:['class_0' 'class_1' 'class_2']
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
pd.options.display.max_rows = 178
data
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# 5      14.20        1.76  2.45               15.2      112.0           3.27
# 6      14.39        1.87  2.45               14.6       96.0           2.50
# 7      14.06        2.15  2.61               17.6      121.0           2.60
# 8      14.83        1.64  2.17               14.0       97.0           2.80
# 9      13.86        1.35  2.27               16.0       98.0           2.98
# 10     14.10        2.16  2.30               18.0      105.0           2.95
# ...

# %%
lista = [1,2,3,4,5]
lista
# Out:
# [1, 2, 3, 4, 5]

# %%
np.array(lista)
# Out:
# array([1, 2, 3, 4, 5])

# %%
listb = ["1",2,3.,4,5]
listb
# Out:
# ['1', 2, 3.0, 4, 5]

# %%
np.array(listb)
# Out:
# array(['1', '2', '3.0', '4', '5'], dtype='<U32')

# %%
a1 = pd.Series([1,3,6, np.nan, 44, 1])
print(type(a1))
a1
# Out:
# <class 'pandas.core.series.Series'>
# 0     1.0
# 1     3.0
# 2     6.0
# 3     NaN
# 4    44.0
# 5     1.0
# dtype: float64

# %%
a2 = pd.Series([1,2,3], index = ['a','b','c'])
print(type(a2))
a2
# Out:
# <class 'pandas.core.series.Series'>
# a    1
# b    2
# c    3
# dtype: int64

# %%
a2['c']
# Out:
# 3

# %%
print(type(data.head(5)['alcohol']))
data.head(5)['alcohol']
# Out:
# <class 'pandas.core.series.Series'>
# 0    14.23
# 1    13.20
# 2    13.16
# 3    14.37
# 4    13.24
# Name: alcohol, dtype: float64

# %%
print(type(data['alcohol'].head(5)))
data['alcohol'].head(5)
# Out:
# <class 'pandas.core.series.Series'>
# 0    14.23
# 1    13.20
# 2    13.16
# 3    14.37
# 4    13.24
# Name: alcohol, dtype: float64

# %%
data[['alcohol']].head(5)
# Out:
#    alcohol
# 0    14.23
# 1    13.20
# 2    13.16
# 3    14.37
# 4    13.24

# %%
type(data[['alcohol']])
# Out:
# pandas.core.frame.DataFrame

# %%
np.random.randn(6,4)
# Out:
# array([[-1.03203791, -0.44576182,  0.39281314, -0.43034321],
#        [ 0.75521324,  0.36930378,  0.91173292, -0.71658032],
#        [-0.8605605 ,  0.56670568,  2.23746045,  1.27915366],
#        [-1.75088357, -0.25801827,  1.11981577,  1.63227409],
#        [-0.2159771 , -0.53343272,  0.01769217,  1.37544251],
#        [-0.17981323,  0.09760229,  1.21905769, -0.02027111]])

# %%
df = pd.DataFrame(np.random.randn(6,4),columns = ['a','b','c','d'])
print(type(df))
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
#           a         b         c         d
# 0  0.547375  0.694750  0.065166  0.231846
# 1 -0.712075  0.028610 -1.586657  0.697746
# 2 -0.155154 -0.196349  0.128807 -0.038805
# 3 -0.135287  0.411163  1.176160  0.344604
# 4  1.269757 -0.293311 -1.473031  1.797177
# 5  0.063271 -0.640293  0.263616 -1.490269

# %%
data.add(1).head(3)
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    15.23        2.71  3.43               16.6      128.0           3.80
# 1    14.20        2.78  3.14               12.2      101.0           3.65
# 2    14.16        3.36  3.67               19.6      102.0           3.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        4.06                  1.28             3.29             6.64  2.04
# 1        3.76                  1.26             2.28             5.38  2.05
# 2        4.24                  1.30             3.81             6.68  2.03
#
#    od280/od315_of_diluted_wines  proline  target
# 0                          4.92   1066.0       1
# 1                          4.40   1051.0       1
# 2                          4.17   1186.0       1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   alcohol                       178 non-null    float64
#  1   malic_acid                    178 non-null    float64
#  2   ash                           178 non-null    float64
#  3   alcalinity_of_ash             178 non-null    float64
#  4   magnesium                     178 non-null    float64
#  5   total_phenols                 178 non-null    float64
#  6   flavanoids                    178 non-null    float64
#  7   nonflavanoid_phenols          178 non-null    float64
#  8   proanthocyanins               178 non-null    float64
#  9   color_intensity               178 non-null    float64
#  10  hue                           178 non-null    float64
#  11  od280/od315_of_diluted_wines  178 non-null    float64
# ...

# %%
data.describe()
# Out:
#           alcohol  malic_acid         ash  alcalinity_of_ash   magnesium  \
# count  178.000000  178.000000  178.000000         178.000000  178.000000
# mean    13.000618    2.336348    2.366517          19.494944   99.741573
# std      0.811827    1.117146    0.274344           3.339564   14.282484
# min     11.030000    0.740000    1.360000          10.600000   70.000000
# 25%     12.362500    1.602500    2.210000          17.200000   88.000000
# 50%     13.050000    1.865000    2.360000          19.500000   98.000000
# 75%     13.677500    3.082500    2.557500          21.500000  107.000000
# max     14.830000    5.800000    3.230000          30.000000  162.000000
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# ...

# %%
data.columns
# Out:
# Index(['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium',
#        'total_phenols', 'flavanoids', 'nonflavanoid_phenols',
#        'proanthocyanins', 'color_intensity', 'hue',
#        'od280/od315_of_diluted_wines', 'proline', 'target'],
#       dtype='object')

# %%
data.sort_values(by='alcohol').head(5)
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 115    11.03        1.51  2.20               21.5       85.0           2.46
# 113    11.41        0.74  2.50               21.0       88.0           2.48
# 120    11.45        2.40  2.42               20.0       96.0           2.90
# 110    11.46        3.74  1.82               19.5      107.0           3.18
# 121    11.56        2.05  3.23               28.5      119.0           3.18
#
#      flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 115        2.17                  0.52             2.01             1.90  1.71
# 113        2.01                  0.42             1.44             3.08  1.10
# 120        2.79                  0.32             1.83             3.25  0.80
# 110        2.58                  0.24             3.58             2.90  0.75
# 121        5.08                  0.47             1.87             6.00  0.93
#
# ...

# %%
data['alcohol'].head(5)
# Out:
# 0    14.23
# 1    13.20
# 2    13.16
# 3    14.37
# 4    13.24
# Name: alcohol, dtype: float64

# %%
data['alcohol'] [3:5]
# Out:
# 3    14.37
# 4    13.24
# Name: alcohol, dtype: float64

# %%
data[3:5]['alcohol']
# Out:
# 3    14.37
# 4    13.24
# Name: alcohol, dtype: float64

# %%
data [['alcohol','malic_acid']].head(5)
# Out:
#    alcohol  malic_acid
# 0    14.23        1.71
# 1    13.20        1.78
# 2    13.16        2.36
# 3    14.37        1.95
# 4    13.24        2.59

# %%
data [['alcohol','malic_acid']] [5:10]
# Out:
#    alcohol  malic_acid
# 5    14.20        1.76
# 6    14.39        1.87
# 7    14.06        2.15
# 8    14.83        1.64
# 9    13.86        1.35

# %%
data [5:10] [['alcohol','malic_acid']]
# Out:
#    alcohol  malic_acid
# 5    14.20        1.76
# 6    14.39        1.87
# 7    14.06        2.15
# 8    14.83        1.64
# 9    13.86        1.35

# %%
data.loc[5:10,['alcohol','malic_acid']]
# Out:
#     alcohol  malic_acid
# 5     14.20        1.76
# 6     14.39        1.87
# 7     14.06        2.15
# 8     14.83        1.64
# 9     13.86        1.35
# 10    14.10        2.16

# %%
data[data['alcohol'] > 14]
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 5      14.20        1.76  2.45               15.2      112.0           3.27
# 6      14.39        1.87  2.45               14.6       96.0           2.50
# 7      14.06        2.15  2.61               17.6      121.0           2.60
# 8      14.83        1.64  2.17               14.0       97.0           2.80
# 10     14.10        2.16  2.30               18.0      105.0           2.95
# 11     14.12        1.48  2.32               16.8       95.0           2.20
# 13     14.75        1.73  2.39               11.4       91.0           3.10
# 14     14.38        1.87  2.38               12.0      102.0           3.30
# 16     14.30        1.92  2.72               20.0      120.0           2.80
# ...

# %%
data[data['target'].isin([1,2])]
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 59     12.37        0.94  1.36               10.6       88.0           1.98
# 60     12.33        1.10  2.28               16.0      101.0           2.05
# 61     12.64        1.36  2.02               16.8      100.0           2.02
# 62     13.67        1.25  1.92               18.0       94.0           2.10
# 63     12.37        1.13  2.16               19.0       87.0           3.50
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
data.apply(lambda x: x+1).head(5)
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    15.23        2.71  3.43               16.6      128.0           3.80
# 1    14.20        2.78  3.14               12.2      101.0           3.65
# 2    14.16        3.36  3.67               19.6      102.0           3.80
# 3    15.37        2.95  3.50               17.8      114.0           4.85
# 4    14.24        3.59  3.87               22.0      119.0           3.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        4.06                  1.28             3.29             6.64  2.04
# 1        3.76                  1.26             2.28             5.38  2.05
# 2        4.24                  1.30             3.81             6.68  2.03
# 3        4.49                  1.24             3.18             8.80  1.86
# 4        3.69                  1.39             2.82             5.32  2.04
#
#    od280/od315_of_diluted_wines  proline  target
# ...

# %%
data['alcohol'].apply(lambda x: x+2).head(5)
# Out:
# 0    16.23
# 1    15.20
# 2    15.16
# 3    16.37
# 4    15.24
# Name: alcohol, dtype: float64

# %%
data['alcohol'].map(lambda x: x+2).head(5)
# Out:
# 0    16.23
# 1    15.20
# 2    15.16
# 3    16.37
# 4    15.24
# Name: alcohol, dtype: float64

# %%
data.apply(lambda x: x+3).head(5)
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    17.23        4.71  5.43               18.6      130.0           5.80
# 1    16.20        4.78  5.14               14.2      103.0           5.65
# 2    16.16        5.36  5.67               21.6      104.0           5.80
# 3    17.37        4.95  5.50               19.8      116.0           6.85
# 4    16.24        5.59  5.87               24.0      121.0           5.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        6.06                  3.28             5.29             8.64  4.04
# 1        5.76                  3.26             4.28             7.38  4.05
# 2        6.24                  3.30             5.81             8.68  4.03
# 3        6.49                  3.24             5.18            10.80  3.86
# 4        5.69                  3.39             4.82             7.32  4.04
#
#    od280/od315_of_diluted_wines  proline  target
# ...

# %%
data.map(lambda x: x+2).head(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 data.map(lambda x: x+2).head(5)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'map'

# %%
data.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  target
# ...

# %%
data.groupby(by='target').sum()
# Out:
#         alcohol  malic_acid     ash  alcalinity_of_ash  magnesium  \
# target
# 0        810.94      118.63  144.88             1005.2     6274.0
# 1        871.79      137.22  159.38             1436.9     6713.0
# 2        631.38      160.02  116.98             1028.0     4767.0
#
#         total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# target
# 0              167.57      175.96                 17.11           112.06
# 1              160.38      147.74                 25.82           115.75
# 2               80.58       37.51                 21.48            55.37
#
#         color_intensity     hue  od280/od315_of_diluted_wines  proline
# target
# 0            326.170000  62.660                        186.31  65827.0
# 1            219.150000  74.996                        197.76  36885.0
# 2            355.019999  32.770                         80.81  30235.0

# %%
data.groupby(by='target').mean()
# Out:
#           alcohol  malic_acid       ash  alcalinity_of_ash   magnesium  \
# target
# 0       13.744746    2.010678  2.455593          17.037288  106.338983
# 1       12.278732    1.932676  2.244789          20.238028   94.549296
# 2       13.153750    3.333750  2.437083          21.416667   99.312500
#
#         total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# target
# 0            2.840169    2.982373              0.290000         1.899322
# 1            2.258873    2.080845              0.363662         1.630282
# 2            1.678750    0.781458              0.447500         1.153542
#
#         color_intensity       hue  od280/od315_of_diluted_wines      proline
# target
# 0              5.528305  1.062034                      3.157797  1115.711864
# 1              3.086620  1.056282                      2.785352   519.507042
# 2              7.396250  0.682708                      1.683542   629.895833

# %%
for i in data .groupby(by='target'):
 print(i)
# Out:
# (0,     alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0     14.23        1.71  2.43               15.6      127.0           2.80
# 1     13.20        1.78  2.14               11.2      100.0           2.65
# 2     13.16        2.36  2.67               18.6      101.0           2.80
# 3     14.37        1.95  2.50               16.8      113.0           3.85
# 4     13.24        2.59  2.87               21.0      118.0           2.80
# 5     14.20        1.76  2.45               15.2      112.0           3.27
# 6     14.39        1.87  2.45               14.6       96.0           2.50
# 7     14.06        2.15  2.61               17.6      121.0           2.60
# 8     14.83        1.64  2.17               14.0       97.0           2.80
# 9     13.86        1.35  2.27               16.0       98.0           2.98
# 10    14.10        2.16  2.30               18.0      105.0           2.95
# ...

# %%
data.groupby(by='target').apply(lambda x: x.sort_values(by= ['alcohol'], ascending=False)[1:2])
# Out:
#             alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  \
# target
# 0      13     14.75        1.73  2.39               11.4       91.0
# 1      62     13.67        1.25  1.92               18.0       94.0
# 2      172    14.16        2.51  2.48               20.0       91.0
#
#             total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# target
# 0      13            3.10        3.69                  0.43             2.81
# 1      62            2.10        1.79                  0.32             0.73
# 2      172           1.68        0.70                  0.44             1.24
#
#             color_intensity   hue  od280/od315_of_diluted_wines  proline  \
# target
# 0      13               5.4  1.25                          2.73   1150.0
# 1      62               3.8  1.23                          2.46    630.0
# 2      172              9.7  0.62                          1.71    660.0
#
#             target
# target
# 0      13        0
# ...

# %%
data[data['target']==0]['alcohol'].sort_values()
# Out:
# 23    12.85
# 21    12.93
# 37    13.05
# 25    13.05
# 44    13.05
# 50    13.05
# 38    13.07
# 2     13.16
# 1     13.20
# 4     13.24
# 43    13.24
# 36    13.28
# 57    13.29
# 27    13.30
# 26    13.39
# 41    13.41
# 35    13.48
# 24    13.50
# 34    13.51
# 55    13.56
# 40    13.56
# 31    13.58
# 15    13.63
# 19    13.64
# 32    13.68
# 22    13.71
# 58    13.72
# 30    13.73
# 54    13.74
# 12    13.75
# 33    13.76
# 53    13.77
# 52    13.82
# 17    13.83
# 51    13.83
# 9     13.86
# 28    13.87
# 42    13.88
# 47    13.90
# 49    13.94
# 29    14.02
# 20    14.06
# 7     14.06
# 10    14.10
# 48    14.10
# 11    14.12
# 18    14.19
# 5     14.20
# 45    14.21
# 39    14.22
# 56    14.22
# 0     14.23
# 16    14.30
# 3     14.37
# 46    14.38
# 14    14.38
# 6     14.39
# 13    14.75
# 8     14.83
# Name: alcohol, dtype: float64
